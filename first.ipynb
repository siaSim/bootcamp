# %% [markdown]
# # 2026-03-20

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print('안녕 파이썬')
# Out:
# 안녕 파이썬

# %%
py -m pip list
# Out:
#   Cell In[1], line 1
#     py -m pip list
#           ^
# SyntaxError: invalid syntax
